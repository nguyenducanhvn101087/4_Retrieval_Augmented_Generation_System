# %% [markdown]
# # How to build a RAG

# %% [markdown]
# ## Install - import - env and global variables

# %%
# Pip install pandas, sentence_transformers and newspaper3k
# %pip install pandas
# %pip install pyarrow
# %pip install sentence_transformers
# %pip install newspaper3k
# %pip install openai
# %pip install markdown

# %%
# Standard library import
import os
import requests
from datetime import datetime, timedelta
import time
from pathlib import Path
# Package for data transformation and embedding
import pandas as pd
from sentence_transformers import SentenceTransformer
import torch
from newspaper import Article
from openai import AzureOpenAI
import markdown
# Out:
# /opt/conda/lib/python3.12/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
# Set enviornnement variable
# %env NEWS_API_KEY=9c40f9b0d5f0469ca9871366a8ace66b
# %env AZURE_OPENAI_ENDPOINT=https://pdd-pilot.openai.azure.com/
# %env AZURE_OPENAI_API_KEY=f9ca39007ce541ed9a377100ff0c3e1e
# Out:
# env: NEWS_API_KEY=9c40f9b0d5f0469ca9871366a8ace66b
# env: AZURE_OPENAI_ENDPOINT=https://pdd-pilot.openai.azure.com/
# env: AZURE_OPENAI_API_KEY=f9ca39007ce541ed9a377100ff0c3e1e

# %%
# !!!UPDATE!!!
PATH_DF_SPORTS = Path("/home", "nguyea37", "training", "RAG_WS_15Aug24","df_sports.parquet")
PATH_DF_SPORTS_US_WOMEN_BB = Path("/home", "nguyea37", "training", "RAG_WS_15Aug24","df_sports_us_women_bb.parquet")

# %% [markdown]
# ## 0. !!DO NOT RUN THIS SECTION!! Getting data
#
# Getting sports news from NewsAPI. NewsAPI is an API providing articles from various data sources.
# Please create an account and get your API key.
#
# We will scrape data with the following filters:
# - Articles containing the keywords `euro 2024` and `uefa`
# - Articles published between `2024-07-07` and `2024-07-25`
# - Articles in English only (`en`)
#
# In the latest version of the provided notebook Mathieu specified "0. !!DO NOT RUN THIS SECTION!! Getting data". The main reason is that he did not want to share his own private API key with the rest of Roche ☺️. That's why he saved the df_sports.parquet for us to use. Please feel free to directly use the provided df_sports.parquet data.
#
# If you want to register to https://newsapi.org and create your own API key, please feel free to do so. Once you obtain the key, please update the cell "# Set enviornnement variable" in notebook to supply the value:
# ```
# %env NEWS_API_KEY=your-secret-api-key-here
# ```
#
# After that you might need to adjust the five_days_ago and one_month_ago so that you can get non-empty news articles about "uefa" and "euro 2024". For example, the following worked for me:
# ```
# five_days_ago = '09-08-2024'
# one_month_ago = '02-07-2024'
# ```
#
# If successful, you should see response 200 like this:
# ```
# <Response [200]>
# https://newsapi.org/v2/everything?q=uefa&from=09-08-2024&to=02-07-2024&apiKey=8bd87073bb9b4cbeafb266b73cc53a91&language=en&page=1
# ```

# %%
# Get today's date
today = datetime.today()

# Calculate yesterday's date
five_days_ago = '09-08-2024'#(today - timedelta(days=5)).strftime('%d-%m-%Y')
# 29 days ago
one_month_ago = '02-07-2024'# (today - timedelta(days=23)).strftime('%d-%m-%Y')

# %%
# Function to fetch sports articles
def fetch_sports_articles(
        key_word: str,
        nb_pages: int
    )-> list[dict]:
    l_articles = []
    base_url = 'https://newsapi.org/v2/everything'
    for i in range(1, nb_pages+1):
        params = {
            'q': key_word,
            'from': five_days_ago,
            'to': one_month_ago,
            'apiKey': os.getenv("NEWS_API_KEY"),
            'language': 'en',
            'page': i
        }
        response = requests.get(base_url, params=params)
        print(response)
        print(response.url)
        if response.status_code == 200:
            data = response.json()
            articles = data.get('articles', [])
            l_articles += articles
    return l_articles

# %%
# Results for each keyword as a list of dictionnaries
# uefa = fetch_sports_articles(key_word = "uefa", nb_pages = 5)
# euro2024 = fetch_sports_articles(key_word = "euro 2024", nb_pages = 5)
wnba         = fetch_sports_articles(key_word = "wnba", nb_pages = 5)
olympics2024 = fetch_sports_articles(key_word = "olympics 2024", nb_pages = 5)
# Out:
# <Response [200]>
# https://newsapi.org/v2/everything?q=wnba&from=09-08-2024&to=02-07-2024&apiKey=9c40f9b0d5f0469ca9871366a8ace66b&language=en&page=1
# <Response [200]>
# https://newsapi.org/v2/everything?q=wnba&from=09-08-2024&to=02-07-2024&apiKey=9c40f9b0d5f0469ca9871366a8ace66b&language=en&page=2
# <Response [200]>
# https://newsapi.org/v2/everything?q=wnba&from=09-08-2024&to=02-07-2024&apiKey=9c40f9b0d5f0469ca9871366a8ace66b&language=en&page=3
# <Response [200]>
# https://newsapi.org/v2/everything?q=wnba&from=09-08-2024&to=02-07-2024&apiKey=9c40f9b0d5f0469ca9871366a8ace66b&language=en&page=4
# <Response [200]>
# https://newsapi.org/v2/everything?q=wnba&from=09-08-2024&to=02-07-2024&apiKey=9c40f9b0d5f0469ca9871366a8ace66b&language=en&page=5
# <Response [200]>
# https://newsapi.org/v2/everything?q=olympics+2024&from=09-08-2024&to=02-07-2024&apiKey=9c40f9b0d5f0469ca9871366a8ace66b&language=en&page=1
# <Response [200]>
# https://newsapi.org/v2/everything?q=olympics+2024&from=09-08-2024&to=02-07-2024&apiKey=9c40f9b0d5f0469ca9871366a8ace66b&language=en&page=2
# <Response [200]>
# https://newsapi.org/v2/everything?q=olympics+2024&from=09-08-2024&to=02-07-2024&apiKey=9c40f9b0d5f0469ca9871366a8ace66b&language=en&page=3
# <Response [200]>
# https://newsapi.org/v2/everything?q=olympics+2024&from=09-08-2024&to=02-07-2024&apiKey=9c40f9b0d5f0469ca9871366a8ace66b&language=en&page=4
# <Response [200]>
# https://newsapi.org/v2/everything?q=olympics+2024&from=09-08-2024&to=02-07-2024&apiKey=9c40f9b0d5f0469ca9871366a8ace66b&language=en&page=5

# %%
# Create a pandas dataframe from the concatenation of the 3 lists
# df = pd.DataFrame(uefa+euro2024)
df = pd.DataFrame(wnba+olympics2024)

# %%
df
# Out:
#                                                 source  \
# 0          {'id': None, 'name': 'Yahoo Entertainment'}
# 1                          {'id': None, 'name': 'NPR'}
# 2                          {'id': None, 'name': 'NPR'}
# 3                          {'id': None, 'name': 'NPR'}
# 4                          {'id': None, 'name': 'NPR'}
# ..                                                 ...
# 995                     {'id': 'time', 'name': 'Time'}
# 996  {'id': 'bleacher-report', 'name': 'Bleacher Re...
# 997                  {'id': None, 'name': 'HYPEBEAST'}
# 998                     {'id': 'time', 'name': 'Time'}
# 999             {'id': 'buzzfeed', 'name': 'Buzzfeed'}
#
#                                       author  \
# 0                              Anna Washenko
# 1                                       None
# 2                                Scott Simon
# 3                              Gus Contreras
# 4                             Becky Sullivan
# ..                                       ...
# 995  Sean Gregory/Paris and Alice Park/Paris
# 996                               Adam Wells
# 997           info@hypebeast.com (Hypebeast)
# 998                      Katherine Pomerantz
# 999                             Matt Stopera
#
#                                                  title  \
# 0    NBA TV rights go to ESPN, NBC and Amazon as TN...
# 1    Iowa basketball phenom Caitlin Clark plans to ...
# 2    Saturday Sports: WNBA All-Star game, Kansas Ci...
# 3    WNBA All-Star game will showcase Team USA play...
# 4    The WNBA, capturing excitement around Caitlin ...
# ..                                                 ...
# 995  What It Was Like on the Seine During the Paris...
# 996  Windhorst: LeBron James, Steph Curry Eye Teami...
# 997  Dior Names Olympic Skater Aurélien Giraud Its ...
# 998  Behind the Photo: How Olympic Photographer Jer...
# 999  Literally Just 43 Very, Very Funny Tweets Abou...
#
#                                            description  \
# 0    The NBA and WNBA have inked deals for where ga...
# 1    Caitlin Clark, who is on the verge of becoming...
# 2    The WNBA All-Star game takes place Saturday. A...
# 3    It's a big weekend for women's basketball. NPR...
# 4    With record attendance and viewership, the WNB...
# ..                                                 ...
# 995  In the end, Paris gave us an Olympic opener we...
# 996  After rumors earlier in the day that the Golde...
# 997  Champion skateboarder Aurélien Giraud is the n...
# 998  Brouillet’s photo of Brazilian surfer Gabriel ...
# 999  I would like to dedicate this post to Raygun f...
#
#                                                    url  \
# 0    https://consent.yahoo.com/v2/collectConsent?se...
# 1    https://www.npr.org/2024/02/29/1235041451/cait...
# 2    https://www.npr.org/2024/07/20/nx-s1-5046381/s...
# 3    https://www.npr.org/2024/07/19/nx-s1-5044781/w...
# 4    https://www.npr.org/2024/06/11/g-s1-3807/wnba-...
# ..                                                 ...
# 995  https://time.com/7004283/paris-olympics-openin...
# 996  https://bleacherreport.com/articles/10109381-w...
# 997  https://hypebeast.com/2024/2/dior-olympic-skat...
# 998  https://time.com/7005239/olympics-surfing-phot...
# 999  https://www.buzzfeed.com/mjs538/olympic-week-2...
#
#                                             urlToImage           publishedAt  \
# 0                                                 None  2024-07-24T23:08:11Z
# 1    https://media.npr.org/assets/img/2024/02/29/ap...  2024-02-29T22:12:57Z
# 2    https://media.npr.org/include/images/facebook-...  2024-07-20T11:57:45Z
# 3    https://media.npr.org/include/images/facebook-...  2024-07-19T20:37:18Z
# 4    https://npr.brightspotcdn.com/dims3/default/st...  2024-06-11T08:00:00Z
# ..                                                 ...                   ...
# 995  https://api.time.com/wp-content/uploads/2024/0...  2024-07-27T00:06:20Z
# 996  https://media.bleacherreport.com/image/upload/...  2024-02-14T16:58:28Z
# 997  https://image-cdn.hypb.st/https%3A%2F%2Fhypebe...  2024-02-07T17:52:16Z
# 998  https://api.time.com/wp-content/uploads/2024/0...  2024-07-30T02:00:00Z
# 999  https://img.buzzfeed.com/buzzfeed-static/stati...  2024-08-10T10:37:34Z
#
#                                                content
# 0    If you click 'Accept all', we and our partners...
# 1    Iowa guard Caitlin Clark claps during the seco...
# 2    The WNBA All-Star game takes place Saturday. A...
# 3    It's a big weekend for women's basketball. NPR...
# 4    More than 400,000 people attended WNBA games i...
# ..                                                 ...
# 995  Lady Gaga opened up the artistic portion of th...
# 996  Ezra Shaw/Getty Images\r\nAfter rumors earlier...
# 997  Champion skateboarder Aurélien Giraud is the n...
# 998  Every four years, a few lucky photographers co...
# 999  Obsessed with the fact that, because Rebeca An...
#
# [1000 rows x 8 columns]

# %%
# Utility function for extracting the content of the article using newspaper3k
def _extract_content_from_article(url: str):
    try:
        article = Article(url)
        article.download()
        article.parse()
        return article.text
    except:
        return ''

# %%
# Utility function for chunking
def _chunking(s: str, chunk_size: int):
    return [
        s[i:i+chunk_size] 
        for i in range(0, len(s), chunk_size)
    ]

# %%
def clean_and_chunking(df: pd.DataFrame)-> pd.DataFrame:
    # Filter out empty description / titles
    df = df[(df["title"] != "[Removed]") | (df["description"] != "[Removed]")]
    # Scrape the full content of the article using newspaper3k (NewsAPI doesn't provide the full content)
    df.loc[:, "content"] = (
        df["url"]
        .apply(lambda x: _extract_content_from_article(x))
    )
    # Chunk the content with `chunk_size=500`
    df.loc[:, "chunked_content"] = (
        df["content"]
        .apply(lambda x: _chunking(s = x, chunk_size = 500))
    )
    # chunked_content contains list of string with size <= 500
    df = (
        df
        .explode("chunked_content")
        .dropna(subset=['chunked_content'])
        .reset_index(drop=True)
    )
    return df[["author", "title", "url", "publishedAt", "chunked_content"]]

# %%
# Clean the dataframe and chunk the article content
df = clean_and_chunking(df = df)
# Out:
# /tmp/ipykernel_3852/479457234.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, "chunked_content"] = (

# %%
# Save the dataframe to parquet
# df.to_parquet(PATH_DF_SPORTS)
df.to_parquet(PATH_DF_SPORTS_US_WOMEN_BB)

# %% [markdown]
# ## 1. Generate the embeddings
#
# The step consists of generating the embeddings from the chunked article content.
#
# Embeddings are vector representations of data, typically used in natural language processing and machine learning. They map high-dimensional data, like words or images, into lower-dimensional continuous vector spaces. This transformation captures semantic relationships, making similar items have closer vectors.
#
# The column `"chunked_content"` in the DataFrame `df` contains chunks of articles with a size $\leq 500$ characters.
#
# We will use the library `sentence_transformers` to generate the embeddings for each chunk. The embedding produces a 768-dimensional vector.

# %%
# df = pd.read_parquet(PATH_DF_SPORTS)
df = pd.read_parquet(PATH_DF_SPORTS_US_WOMEN_BB)

# %%
df
# Out:
#                    author                                              title  \
# 0                    None  Iowa basketball phenom Caitlin Clark plans to ...
# 1                    None  Iowa basketball phenom Caitlin Clark plans to ...
# 2                    None  Iowa basketball phenom Caitlin Clark plans to ...
# 3                    None  Iowa basketball phenom Caitlin Clark plans to ...
# 4             Scott Simon  Saturday Sports: WNBA All-Star game, Kansas Ci...
# ...                   ...                                                ...
# 7301  Katherine Pomerantz  Behind the Photo: How Olympic Photographer Jer...
# 7302  Katherine Pomerantz  Behind the Photo: How Olympic Photographer Jer...
# 7303  Katherine Pomerantz  Behind the Photo: How Olympic Photographer Jer...
# 7304  Katherine Pomerantz  Behind the Photo: How Olympic Photographer Jer...
# 7305         Matt Stopera  Literally Just 43 Very, Very Funny Tweets Abou...
#
#                                                     url           publishedAt  \
# 0     https://www.npr.org/2024/02/29/1235041451/cait...  2024-02-29T22:12:57Z
# 1     https://www.npr.org/2024/02/29/1235041451/cait...  2024-02-29T22:12:57Z
# 2     https://www.npr.org/2024/02/29/1235041451/cait...  2024-02-29T22:12:57Z
# 3     https://www.npr.org/2024/02/29/1235041451/cait...  2024-02-29T22:12:57Z
# 4     https://www.npr.org/2024/07/20/nx-s1-5046381/s...  2024-07-20T11:57:45Z
# ...                                                 ...                   ...
# 7301  https://time.com/7005239/olympics-surfing-phot...  2024-07-30T02:00:00Z
# 7302  https://time.com/7005239/olympics-surfing-phot...  2024-07-30T02:00:00Z
# 7303  https://time.com/7005239/olympics-surfing-phot...  2024-07-30T02:00:00Z
# 7304  https://time.com/7005239/olympics-surfing-phot...  2024-07-30T02:00:00Z
# 7305  https://www.buzzfeed.com/mjs538/olympic-week-2...  2024-08-10T10:37:34Z
#
#                                         chunked_content
# 0     Iowa basketball phenom Caitlin Clark plans to ...
# 1      post on the X social media platform. She than...
# 2     tting the boards.\n\nThe guard, with one more ...
# 3     t. Earlier this month, Clark broke Kelsey Plum...
# 4     Saturday Sports: WNBA All-Star game, Kansas Ci...
# ...                                                 ...
# 7301  ia boats capturing the surfing events, which a...
# 7302  ing over 20 images per second, so Brouillet is...
# 7303   knows the waters of Teahupo'o well, having mo...
# 7304  much more comfortable on the media boat, takin...
# 7305  Last week, I rounded up the best tweets from t...
#
# [7306 rows x 5 columns]

# %%
# Selected model from hugging face
model = SentenceTransformer('thenlper/gte-base')

# %%
# Create the embeddings for the article chunks
def create_embeddings(df: pd.DataFrame, model: SentenceTransformer)-> pd.DataFrame:
    embedding = model.encode([x for x in df["chunked_content"].tolist()], show_progress_bar = True)
    return embedding

# %%
news_embedding = create_embeddings(df = df, model = model)
# Out:
# Batches:   0%|          | 0/229 [00:00<?, ?it/s]

# %% [markdown]
# ## 2. Calculate the cosine similarity between the query and the document vectors
#
# 1. Calculate the embedding for the `query` (e.g., question).
# 2. Compute the similarity vector between the `query` and each `document` by using cosine similarity distance metric.
# 3. Identify the indices of the `top_k` similarity scores.
# 4. Retrieve the corresponding documents using these indices.

# %%
# 1. Calulcate the embedding for the query
# QUERY = "Give multiple factors for why France lost euro 2024"
QUERY = "What was the main factor for US women basketball team to win the summer olympics 2024?"
query_embedding = model.encode([QUERY], show_progress_bar = True)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
query_embedding
# Out:
# array([[-7.56371673e-03, -3.84708345e-02, -9.25905257e-03,
#          1.82052311e-02,  4.38780747e-02,  2.06739604e-02,
#          5.22018746e-02,  2.99704429e-02, -3.28086168e-02,
#         -5.90499155e-02,  1.82319861e-02, -1.53562734e-02,
#         -4.88898419e-02,  3.57510298e-02, -1.74108613e-02,
#          6.75951689e-02,  3.89009751e-02,  1.48724942e-02,
#          1.91479903e-02,  3.15222591e-02, -9.34780203e-03,
#          8.36333632e-03,  2.82293209e-03,  1.87512655e-02,
#          1.66486632e-02,  1.25942519e-03,  8.96374322e-03,
#         -5.34010492e-03, -7.11187348e-02,  6.10290095e-03,
#          3.97683680e-02, -5.01913428e-02, -2.26746183e-02,
#          9.37555509e-04,  2.17567682e-02, -2.10640859e-02,
#         -4.77420166e-03,  8.94072559e-03, -4.24933183e-04,
#         -1.80902854e-02, -5.27624227e-02, -2.63359454e-02,
#         -1.33294484e-03,  8.61034356e-03, -6.73992187e-02,
#          8.52909964e-03, -1.63018946e-02,  4.62571383e-02,
#         -2.09315568e-02, -5.06349839e-02, -4.38528955e-02,
#          2.20297519e-02,  8.69880838e-04,  2.47306023e-02,
#          9.31470376e-03,  2.12723073e-02,  6.70839427e-03,
#         -2.04481371e-02, -2.37283986e-02, -9.27537084e-02,
#          1.90337840e-02,  2.75744703e-02,  3.53678949e-02,
#         -7.53387855e-03,  4.30184826e-02,  8.07971414e-03,
#          3.75558026e-02,  2.98252534e-02, -2.87550408e-02,
#         -2.76063886e-02, -5.03974557e-02, -1.10080540e-02,
#         -1.82043705e-02, -6.32070005e-02, -1.10521866e-03,
#         -4.47140597e-02,  4.33074776e-03,  2.06138082e-02,
#          6.61375448e-02,  3.20005007e-02,  2.75447238e-02,
#         -3.69796017e-03, -7.95016158e-03,  4.62790355e-02,
#         -1.84522532e-02, -3.40749323e-02,  1.91473253e-02,
#          7.11608864e-03, -4.86641563e-02,  9.34760720e-02,
#          2.32514273e-03, -6.98116515e-03,  4.54094708e-02,
#          6.56891093e-02, -4.81720235e-05, -3.04938760e-02,
#          5.90354353e-02,  8.69747531e-03,  4.81874507e-04,
#         -1.04980757e-02, -1.98182855e-02, -6.95159212e-02,
#          2.60282162e-04, -1.92455444e-02, -9.71609503e-02,
#         -3.96364778e-02,  3.69218178e-02,  2.30007283e-02,
#          3.00222244e-02,  2.09579640e-03,  3.73195857e-02,
#         -1.66970938e-02,  7.92115461e-03, -2.54050028e-02,
#         -6.42052963e-02,  5.72538488e-02,  4.90956977e-02,
#         -5.96628524e-03, -2.68514790e-02,  1.03538390e-02,
#          1.78675894e-02,  3.90066840e-02,  3.00333500e-02,
#          7.54007325e-02,  1.03568844e-02,  4.90323231e-02,
#          7.87319802e-03,  4.43973579e-02,  1.49218123e-02,
#         -5.12481108e-02,  1.56755149e-02,  3.17640156e-02,
#         -1.68822687e-02, -2.17564441e-02,  8.55349191e-03,
#         -1.49098746e-02, -8.46242718e-03, -6.41281018e-04,
#          1.33454856e-02,  3.86192724e-02,  1.10765239e-02,
#          1.52215431e-03,  2.61455681e-03, -1.12033570e-02,
#          2.48738565e-02, -3.01651023e-02,  9.15111229e-03,
#         -3.75653617e-02, -3.46025899e-02,  3.17837559e-02,
#          5.63080190e-03,  1.29812546e-02,  2.31960956e-02,
#         -2.32407693e-02, -3.73144262e-02,  2.58278362e-02,
#          2.94242091e-02, -7.12061534e-03, -5.63787259e-02,
#          5.69557026e-02,  3.47890258e-02, -4.04124102e-03,
#          1.52643975e-02,  1.77016258e-02, -3.00923400e-02,
#          3.15437019e-02,  1.11406688e-02,  7.62615632e-03,
#         -6.10250002e-03,  3.10628824e-02, -3.02258749e-02,
#         -1.35130631e-02,  5.99069782e-02,  2.89760809e-02,
#         -2.74056382e-02, -2.42453534e-02,  5.91268800e-02,
#         -9.12540313e-03,  5.77985262e-03,  2.57320981e-02,
#         -9.83509272e-02,  2.35364567e-02,  4.18201089e-03,
#          1.18322391e-02,  3.49287614e-02, -6.70068488e-02,
#          5.42300716e-02, -3.79963852e-02,  8.16352665e-03,
#          1.09786997e-02, -5.34377024e-02, -4.98809405e-02,
#          3.83184012e-03, -7.01166922e-03,  8.87220204e-02,
#         -4.59071435e-02, -2.91754548e-02,  2.39786711e-02,
#         -5.24412049e-03,  2.56514419e-02,  2.02361532e-02,
#          9.84678324e-03,  1.10403541e-02, -2.52810605e-02,
#         -4.10551056e-02,  3.47894733e-03,  5.08858114e-02,
#          1.14792753e-02, -1.09877642e-02,  4.86861505e-02,
#         -2.18863524e-02, -1.32517247e-02,  1.37838488e-02,
#         -3.30369882e-02,  1.69099681e-02, -1.66903865e-02,
#          3.99109051e-02,  1.14358524e-02,  2.23670341e-02,
#         -3.82156260e-02,  7.29014501e-02, -1.08716721e-02,
#         -1.37069402e-02,  3.68511304e-03, -1.49627123e-02,
#          7.57809803e-02,  3.58059779e-02, -4.69021127e-02,
#         -6.89050369e-03,  3.92210782e-02, -3.47900344e-03,
#          1.25374496e-02,  1.55285355e-02, -2.47674920e-02,
#          3.71048041e-02,  1.45503227e-02, -3.14242975e-03,
#         -1.76727101e-02,  6.64852485e-02, -5.04821278e-02,
#         -9.16275755e-03,  6.32869974e-02,  2.38532200e-02,
#          6.89445809e-02, -1.02561153e-02, -3.46733332e-02,
#          5.77511601e-02, -4.02916633e-02, -6.18209597e-03,
#         -6.81802928e-02, -3.15756234e-03, -1.87688600e-02,
#          1.20681860e-02,  3.34252324e-03, -6.19563274e-03,
#         -6.61313906e-02,  1.35224760e-02,  1.09809907e-02,
#          9.68887210e-02,  3.53985578e-02,  4.85007325e-03,
#         -6.92024454e-03, -1.07877376e-02, -1.53483246e-02,
#         -3.77776586e-02, -8.19814503e-02, -5.84838912e-02,
#         -2.64488887e-02, -6.84505096e-03, -4.85772733e-03,
#          4.38701883e-02,  3.20053883e-02,  1.01054873e-04,
#         -2.88448501e-02, -1.00513725e-02,  6.04318678e-02,
#          2.26212107e-02, -1.91004761e-02, -2.09929328e-02,
#         -2.13590488e-02,  3.00387330e-02,  4.11580428e-02,
#         -1.38393017e-02, -3.80852148e-02,  3.43665481e-03,
#         -8.38848427e-02, -2.32128310e-04, -3.68729681e-02,
#         -4.46935631e-02,  1.65835093e-03, -1.20917354e-02,
#          2.74517909e-02, -1.70038007e-02, -5.48607716e-03,
#          5.60028851e-02,  2.02157665e-02,  4.72371653e-03,
#          5.06690964e-02, -7.50186574e-03,  2.45616939e-02,
#          1.63571443e-02,  4.90605310e-02, -1.22645097e-02,
#         -3.75030166e-03,  4.54582181e-03, -1.87925510e-02,
#          1.06780753e-02, -3.46868485e-02, -2.16587394e-01,
#         -1.18928673e-02, -1.07962918e-02, -4.14112471e-02,
#          5.33917397e-02, -2.28293035e-02, -2.00006482e-03,
#         -2.30284985e-02, -4.51333337e-02,  1.29848067e-02,
#          1.58937946e-02,  4.02017590e-03,  4.24936088e-03,
#          2.01754384e-02,  2.80012153e-02,  1.34067088e-02,
#          2.05809325e-02, -2.36088932e-02, -1.69121418e-02,
#          4.74045426e-02,  8.50263797e-03, -5.30506819e-02,
#         -3.23254541e-02,  1.20813549e-02,  1.28394505e-02,
#          6.31936863e-02, -1.32732987e-02, -3.88694480e-02,
#         -6.08428866e-02, -5.35458662e-02,  2.46996172e-02,
#         -7.46471062e-03,  2.26829890e-02, -4.07398343e-02,
#          1.07251499e-02, -1.11051155e-02,  3.02758887e-02,
#         -5.79230040e-02, -2.57645417e-02, -1.72346216e-02,
#         -3.43766436e-02, -1.49092134e-02, -1.93988327e-02,
#          2.79840995e-02,  6.00798577e-02,  2.94549800e-02,
#          2.75165364e-02,  1.24268851e-03, -2.35198289e-02,
#          8.89452025e-02, -6.30072318e-03,  1.98369194e-02,
#         -9.41041391e-03,  4.19858005e-03, -2.82350313e-02,
#          8.12315941e-03, -2.50371397e-02,  1.74567308e-02,
#         -1.64986737e-02, -3.67798167e-03, -1.72427595e-02,
#         -4.11945842e-02, -1.23047968e-02, -2.95957029e-02,
#         -3.03433668e-02, -7.72942081e-02, -3.84491719e-02,
#          5.74929314e-03,  2.76609510e-02,  4.78679268e-03,
#         -1.18443146e-02,  2.67720092e-02, -3.75737548e-02,
#         -7.59714320e-02, -7.27212848e-03,  9.86844394e-03,
#          1.85856409e-03, -1.31127406e-02, -3.30221467e-03,
#         -1.13501800e-02, -1.45645384e-02, -2.10177246e-02,
#          2.42073947e-04,  6.84434175e-02,  7.99660105e-03,
#         -4.89875413e-02,  3.17233205e-02,  1.96965076e-02,
#         -5.66608608e-02, -6.97771145e-04,  5.79945743e-02,
#         -2.57098190e-02, -1.46924155e-02,  1.36605492e-02,
#          4.53853123e-02,  2.72865221e-02, -1.73657108e-02,
#         -3.52267064e-02,  3.28208543e-02, -5.16928174e-02,
#          9.75956768e-03, -4.56252992e-02,  6.87307911e-03,
#         -2.97844335e-02, -3.63587961e-03,  1.60350800e-02,
#         -5.55608198e-02, -8.99205264e-03,  8.00872445e-02,
#         -5.37897646e-02,  8.94628316e-02, -2.40027700e-02,
#          1.99112631e-02, -5.16617931e-02,  2.70496905e-02,
#         -4.44106013e-02,  2.98072658e-02,  5.74610531e-02,
#          1.64084174e-02, -2.13972968e-03, -3.82096916e-02,
#          5.44405878e-02, -7.13995099e-02, -7.61730131e-03,
#         -6.95869625e-02, -1.98046304e-02,  9.61335935e-03,
#          1.21084950e-03, -4.01211455e-02,  2.91166035e-03,
#         -2.75105033e-02, -3.12483720e-02,  4.81331795e-02,
#          1.21017732e-02,  4.43846397e-02,  2.61175632e-02,
#         -3.53797227e-02, -4.51613367e-02, -2.45064590e-03,
#         -2.07300670e-02,  3.40881990e-03,  3.00442185e-02,
#         -2.74945311e-02,  3.42074130e-03,  4.53349799e-02,
#          3.40150446e-02, -3.59970890e-02,  9.14892834e-03,
#         -3.37384380e-02,  2.50623338e-02, -2.35682391e-02,
#         -2.94640027e-02,  3.02745495e-02, -7.24751279e-02,
#         -2.63868403e-02, -3.33726779e-02,  8.16978887e-02,
#          3.05553917e-02,  1.91991534e-02, -5.23005091e-02,
#         -3.13544385e-02, -4.51344401e-02, -1.31402696e-02,
#          1.28273061e-02, -1.30435219e-02,  8.95429552e-02,
#          2.15315409e-02, -3.10387146e-02, -2.44472530e-02,
#          1.40532227e-02,  3.37659605e-02, -5.04724793e-02,
#         -4.70792875e-02,  5.72730415e-03, -4.51794118e-02,
#          4.79972027e-02,  2.53543767e-05,  4.16422216e-03,
#          1.00487890e-02,  2.39832457e-02,  6.38171099e-03,
#         -3.06863571e-03, -1.02294916e-02,  4.74147149e-04,
#          3.39363702e-02,  3.55563648e-02, -1.05853695e-02,
#         -3.24044004e-02, -5.05639380e-03, -1.08667137e-03,
#          1.67178810e-02,  9.24733642e-04, -3.26185226e-02,
#          2.67760479e-03, -9.00014862e-02, -5.38908169e-02,
#          3.15872170e-02,  6.16837591e-02, -2.64172368e-02,
#          4.47806567e-02, -4.28159861e-03, -8.33080732e-04,
#         -6.11500517e-02,  1.28860995e-02,  5.07103354e-02,
#         -8.25368762e-02,  3.89136001e-02,  2.34531388e-02,
#          3.59926075e-02,  2.86837742e-02, -5.09421714e-02,
#         -1.40663534e-02, -9.35618859e-03,  2.89407745e-02,
#          1.71130020e-02, -2.64384244e-02,  1.19914794e-02,
#         -4.08938490e-02,  4.38250462e-03, -1.52322641e-02,
#          1.96447894e-02, -3.92507836e-02, -1.94995031e-02,
#         -2.98746247e-02, -2.56207455e-02,  1.89932398e-02,
#         -3.05424184e-02,  3.14333593e-03,  1.30939195e-02,
#         -1.92104168e-02,  1.97080672e-02, -4.59129177e-02,
#          2.79157832e-02,  3.18023600e-02,  3.06872446e-02,
#         -2.39270972e-03,  4.04788880e-03, -2.00793287e-03,
#          3.58874202e-02,  6.62619248e-02, -2.29897853e-02,
#         -3.85350809e-02, -7.75809307e-03, -3.97229828e-02,
#         -2.04442777e-02, -3.25169414e-02, -6.08588308e-02,
#          3.97003666e-02,  8.26568902e-03,  5.63582964e-02,
#         -2.78522372e-02, -1.47142187e-02, -1.66262854e-02,
#         -2.34106760e-02,  4.27294821e-02, -3.73668224e-02,
#         -5.97130172e-02,  2.75965501e-03, -9.66941938e-03,
#         -2.93728393e-02, -1.30882561e-02,  2.30594371e-02,
#         -6.75355941e-02,  9.09496658e-03,  2.58686300e-02,
#          4.45219725e-02, -7.13490881e-03, -1.79555994e-02,
#          2.53076851e-02, -4.07062471e-02, -4.34606383e-03,
#         -8.01577270e-02,  2.23206007e-03, -9.31218080e-03,
#         -7.97054358e-03,  2.28804015e-02,  1.45959957e-02,
#         -2.78241653e-02,  3.33036296e-02, -6.65190890e-02,
#         -3.06297168e-02,  5.95720559e-02, -4.76367697e-02,
#          1.00631071e-02,  3.61555777e-02, -3.71396244e-02,
#         -3.12104113e-02,  1.02505600e-03, -5.47500327e-02,
#          4.24815379e-02, -1.02546765e-03,  2.84673925e-02,
#         -3.73828760e-03,  2.37725712e-02, -2.57098116e-02,
#         -1.11162765e-02,  2.52682716e-02,  6.17144741e-02,
#         -7.51212146e-03,  2.73256879e-02, -7.00095817e-02,
#          7.41842836e-02,  1.66398752e-02,  1.06565524e-02,
#         -1.45674916e-02, -5.02627622e-03, -1.26397805e-02,
#         -7.25375339e-02, -4.94622346e-03,  2.79216673e-02,
#         -2.07352024e-02, -8.12720358e-02,  9.60381031e-02,
#         -1.30305002e-02, -5.90704940e-02, -2.92835012e-03,
#         -1.45490502e-03, -2.26097461e-02, -3.86349065e-03,
#          1.86195690e-02,  7.92005472e-03, -3.81956599e-03,
#          6.67982325e-02,  4.01445851e-02,  5.28927185e-02,
#          5.74701615e-02, -7.92137813e-03,  1.61401853e-02,
#          1.09038213e-02,  8.07697475e-02,  2.09018290e-02,
#          1.11790011e-02,  3.52774113e-02,  6.95067495e-02,
#          1.94702763e-02, -7.59105831e-02,  7.42067816e-04,
#         -5.34348888e-03, -1.15744360e-02,  1.71992350e-02,
#          2.38439087e-02,  2.63028536e-02,  4.33572866e-02,
#          1.15752593e-02,  4.38555852e-02, -4.14461643e-02,
#          3.37712206e-02, -1.19632930e-02,  3.52970921e-02,
#          3.28182243e-02,  4.24106792e-02,  3.80799882e-02,
#         -1.98626332e-02, -2.48252135e-02,  1.86123867e-02,
#          2.22642403e-02,  1.76903624e-02, -5.93792135e-03,
#         -5.14513813e-02,  1.87802799e-02,  4.86589270e-03,
#         -4.95946445e-02,  9.80665982e-02, -1.97109468e-02,
#         -1.00565637e-02, -4.70050685e-02,  4.33458388e-03,
#         -8.76413193e-03,  3.29306461e-02,  1.78111177e-02,
#         -1.03323003e-02, -1.20192422e-02, -1.82212573e-02,
#          1.53359501e-02,  1.73511021e-02,  4.12738770e-02,
#         -1.04675554e-02, -4.88895290e-02,  9.82392393e-03,
#          2.38107312e-02,  3.31741348e-02,  5.10579848e-04,
#         -7.30436668e-02, -4.13967893e-02, -5.83274625e-02,
#         -2.85211876e-02, -5.93484519e-03,  6.83873221e-02,
#         -3.99012491e-02, -5.05744442e-02, -8.85469001e-03,
#         -4.05222736e-02, -3.02627496e-02, -4.80166776e-03,
#         -1.31474985e-02, -3.90023813e-02,  6.84438348e-02,
#          1.53921936e-02,  2.50891466e-02,  5.82555458e-02,
#          7.08799213e-02,  3.29516106e-03, -1.39514338e-02,
#          2.69770101e-02,  1.77049059e-02,  5.97255528e-02,
#         -3.08208950e-02, -8.97016656e-03, -8.46412778e-02,
#         -5.21876710e-03,  1.63775012e-02, -1.85663626e-02,
#         -9.15780962e-02,  2.88143102e-02, -1.69727975e-03,
#          2.09821220e-02,  6.06698841e-02,  3.59645323e-03,
#          1.97848063e-02, -6.01601191e-02, -2.61256173e-02,
#         -1.60041582e-02, -5.29822633e-02,  9.29985791e-02,
#         -2.27419827e-02,  6.29854947e-02,  3.53959762e-02,
#         -4.25090417e-02, -3.13279852e-02,  2.06117015e-02,
#         -2.46772189e-02, -6.96745003e-03,  9.10863921e-04,
#          4.46954742e-02, -1.99068915e-02, -1.33236066e-01,
#         -2.07931474e-02,  1.73085630e-02, -3.73553159e-03,
#         -7.63823837e-02,  2.70275827e-02, -5.38684428e-04,
#         -3.78500135e-03,  1.62599387e-03, -6.58192299e-03,
#          3.44351586e-03, -3.13236192e-02, -2.06770469e-02,
#         -8.10304005e-03,  2.58844644e-02, -2.17778049e-02,
#         -8.07844196e-03, -5.96270338e-03, -3.82765904e-02,
#          4.07456122e-02, -8.14329926e-03, -1.47821931e-02,
#          4.13494604e-03,  1.96465757e-02,  3.31741176e-03]], dtype=float32)

# %%
# 2. Compute the similarity vector between the `query` and each `document` by applying cosine similarity.
similarity_scores = model.similarity(query_embedding, news_embedding)[0]

# %%
# 3. Identify the indices of the `top_k` similarity scores.
scores, indices = torch.topk(similarity_scores, k=5)

# %%
indices
# Out:
# tensor([5047, 5549, 4676, 5622, 4788])

# %%
# 4. Retrieve the corresponding documents using these indices.
retrieved_context = df.iloc[indices]["chunked_content"].to_list()

# %%
retrieved_context
# Out:
# ["Check out some of the key players headlining the U.S. women's basketball team as it seeks to win its eighth straight gold medal including Dianna Taurasi, Brittney Griner and Breanna Stewart. (1:47)\n\nOpen Extended Reactions\n\nThe 2024 Olympics are almost finished. August 11th will bring final stretch developments in basketball and volleyball, in addition to the closing ceremony. Can the U.S. women's basketball team and U.S. women's volleyball team bring home gold medals in their respective finals?",
#  'Basketball is consistently one of the most anticipated sports at every Olympics, and with LeBron James, Steph Curry, Nikola Jokic, Victor Wembanyama, Breanna Stewart, A’ja Wilson and dozens of other top NBA and WNBA stars competing in Paris, the 2024 Games will be no different. Team USA are heavy favorites on both the men’s and women’s sides, but as we’ve seen many times before in the international game, nothing can be taken for granted, and everything will be exciting.\n\nIf you live in the U.S.,',
#  'U.S. women’s basketball team opens the Olympics with dominant win over Japan\n\ntoggle caption Sameer Al-Doumy/AFP via Getty Images\n\nNPR is in Paris for the 2024 Summer Olympics. For more of our coverage from the games head to our latest updates.\n\nPARIS - The U.S. women’s basketball team extended its historic winning streak on Monday in Lille.\n\nIt wasn’t close.\n\nThe team, which now boasts a 56-game Olympic winning streak, easily defeated Japan 102-76. A’ja Wilson led the way for Team USA with 24 p',
#  "Take a look at the facts and figures from a memorable Olympics, including the American women's dominance in Paris. (1:11)\n\nOpen Extended Reactions\n\nWelcome to the final day of the 2024 Olympics!\n\nThe curtain has closed on the Paris Games, but not before the U.S. women's basketball team capped off an unforgettable journey with a victory in its highly anticipated gold medal match. Editor's Picks How the women's basketball Olympic final was set and could play out Alexa Philippou and Michael Voepel\n",
#  "U.S. women's basketball team defeats France to win eighth straight Olympic gold medal\n\ntoggle caption Gregory Shamus/Getty Images\n\nNPR is in Paris for the 2024 Summer Olympics. For more of our coverage from the Games head to our latest updates.\n\nPARIS – It wasn’t great basketball. But it didn’t have to be. It was just enough.\n\nLed by A'Ja Wilson, who scored 21 points, the U.S. women’s team beat France on Sunday, 67-66, becoming the first basketball team in Olympic history to win eight consecutiv"]

# %% [markdown]
# ## 3. Craft the prompt
#
# In the RAG, we need 3 elements to create the prompt.
# 1. System prompt to specify the task
# 2. Query (e.g: user's question)
# 3. Context (e.g: retrieved information)

# %%
SYSTEM_PROMPT = """
You are a helpful assistant who answers questions based on sports news articles.
"""

# %%
USER_PROMPT = f"""
[USER]
{QUERY}

[CONTEXT]
{' Article: '.join(retrieved_context)}
"""

# %% [markdown]
# ## 4. Generate the answer from GPT-4o
#
# To generate an answer from GPT-4o, we will use the OpenAI client to send a request to Azure OpenAI. This involves setting up the client with the appropriate API keys and endpoint, and then making a request to the GPT-4o model with the desired input. The response from the model will contain the generated answer.

# %%
# Open AI client
client = AzureOpenAI(
    azure_endpoint = os.getenv("AZURE_OPENAI_ENDPOINT"), 
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),  
    api_version="2023-05-15"
)

# %%
response = client.chat.completions.create(
    model="gpt-4o",
    messages= [
        {
            "role": "system",
            "content": SYSTEM_PROMPT
        },
        {
            "role": "user",
            "content": USER_PROMPT
        }
    ]
)

# %%
answer = response.choices[0].message.content

# %%
answer
# Out:
# "The main factor for the U.S. women's basketball team winning the gold medal at the 2024 Summer Olympics was their overall dominance and key performances from star players, particularly A'ja Wilson. Wilson's consistent high-level play, including a significant scoring contribution of 21 points in the final against France, was crucial in securing their eighth consecutive Olympic gold medal. The team's historic winning streak and depth of talent also played a significant role in their success."
